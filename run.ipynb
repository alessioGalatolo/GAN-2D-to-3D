# %% [markdown]
# # GAN2Shape runner
# This script will run our implementation of GAN2Shape on a cloud based environment like Google Colab or Kaggle.
# NOTE: requires linux and a GPU

# %%
# Clone repo
! git clone https://github.com/alessioGalatolo/GAN-2D-to-3D.git

# %%
# %%bash
# MINICONDA_INSTALLER_SCRIPT=Miniconda3-py39_4.10.3-Linux-x86_64.sh
# MINICONDA_PREFIX=/usr/local
# wget https://repo.anaconda.com/miniconda/Miniconda3-py39_4.10.3-Linux-x86_64.sh
# chmod +x $MINICONDA_INSTALLER_SCRIPT
# ./$MINICONDA_INSTALLER_SCRIPT -b -f -p $MINICONDA_PREFIX

# %%
# Install right version of pytorch
# !conda create --name 3D-GAN -y pytorch==1.2.0 torchvision==0.4.0 cudatoolkit=10.0 -c pytorch

# %%
import sys
sys.path.append('/usr/local/lib/python3.6/site-packages')

# %%
# Download and install neural renderer
# !git clone https://github.com/sharf91/neural_renderer.git
# %cd neural_renderer
# !source activate 3D-GAN && python setup.py install

# %%
# Install all other dependencies
# !source activate 3D-GAN && conda install -y numpy pandas distributed ipython lmdb matplotlib Pillow scipy tqdm scikit-image
# !source activate 3D-GAN && conda install -y wandb PyYAML -c conda-forge
# !source activate 3D-GAN && conda install -y -c anaconda ipykernel ipython_genutils
# !source activate 3D-GAN && pip install plotly gif

# %%
# (optional) login into wandb for logging (replace <key> with the one at wandb.ai/authorize)
# !source activate 3D-GAN && wandb login <key>

# %%
# Download data
# %cd ../GAN-2D-to-3D
# !python download_data.py

# %% [markdown]
# ## Run the program

# %%
# With wandb
# !source activate 3D-GAN && python main.py --save-ckpts --category face --wandb

# Without wandb
# !source activate 3D-GAN && python main.py --save-ckpts --category face

# %% [markdown]
# ## Get results (will appear in results/plots and results/htmls)

# %%
# !source activate 3D-GAN && python evaluate_results.py --category face
